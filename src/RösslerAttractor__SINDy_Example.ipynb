# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import solve_ivp
import pysindy as ps

# Rössler attractor
def rossler(t, xyz, a=0.2, b=0.2, c=5.7):
    x, y, z = xyz
    dxdt = -y - z
    dydt = x + a * y
    dzdt = b + z * (x - c)
    return [dxdt, dydt, dzdt]

# Simulate the actual system
t_span = (0, 100)
dt = 0.01
t_eval = np.arange(t_span[0], t_span[1], dt)
initial_condition = [1.0, 1.0, 1.0]
actual_solution = solve_ivp(rossler, t_span, initial_condition, t_eval=t_eval)
x_actual = actual_solution.y.T

# Add noise
noise_strength = 0.5
x_noisy = x_actual + noise_strength * np.random.normal(size = x_actual.shape)

# Fit SINDy model
model = ps.SINDy()
model.fit(X, t = dt)
model.print()

# Simulate SINDy model
x_sindy = model.simulate(initial_condition, t_eval)

# Plot comparison of actual system vs SINDy model
fig = plt.figure(figsize=(12, 5))
ax1 = fig.add_subplot(121, projection = '3d')
ax1.plot(*x_actual.T, color = 'blue', label = 'Actual')
ax1.set_title("Actual Rössler Attractor")
ax1.set_xlabel("x"); ax1.set_ylabel("y"); ax1.set_zlabel("z")

ax2 = fig.add_subplot(122, projection = '3d')
ax2.plot(*x_sindy.T, color = 'orange', label = 'SINDy')
ax2.set_title("SINDy Model")
ax2.set_xlabel("x"); ax2.set_ylabel("y"); ax2.set_zlabel("z")

plt.tight_layout()
plt.show()
# Out:
# (x0)' = -1.000 x1 + -1.000 x2
# (x1)' = 1.000 x0 + 0.200 x1
# (x2)' = 0.201 1 + -5.717 x2 + 1.003 x0 x2

# %%
from sklearn.metrics import mean_squared_error

# Compute MSE per variable and total
mse_x = mean_squared_error(x_actual[:, 0], x_sindy[:, 0])
mse_y = mean_squared_error(x_actual[:, 1], x_sindy[:, 1])
mse_z = mean_squared_error(x_actual[:, 2], x_sindy[:, 2])
mse_total = mean_squared_error(x_actual, x_sindy)

# Print MSE results
print("\nMean Squared Error (MSE) between actual Rössler system and SINDy model:")
print(f"  x: {mse_x:.4f}")
print(f"  y: {mse_y:.4f}")
print(f"  z: {mse_z:.4f}")
print(f"  Total (all variables): {mse_total:.4f}")
# Out:
# Mean Squared Error (MSE) between actual Lorenz system and SINDy model:
#   x: 1.0695
#   y: 1.4464
#   z: 1.0837
#   Total (all variables): 1.1998
